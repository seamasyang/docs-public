# %% [markdown]
# # 1. 简介
#
# ## 背景
# - 数据分散、质量参差不齐、难以挖掘
# - 数据量激增
# - 数据的的复杂性和多样性
# - 实时性需求
#
# ## 简介
# - 数科是一门综合性学科(统计、计科、信科)，其核心是将混乱的数据有效地转化为有价值的见解、知识和洞见
# - 本质：基于数据驱动，旨在从数据中提取知识和洞见，并将其应用于解决实际问题
#
# ## 作用及其意义
# - 数据洞察、决策支持、业务优化
#
# ## 核心内容
# - 数据采集、预处理、数据探索与可视化、特征工程、模型构建与优化、模型评估以及可解释性等几个步骤
#
# ## 核心技术
# - 统计分析、机器学习、深度学习、数据挖掘、数据可视化、大数据处理，数仓，数湖
