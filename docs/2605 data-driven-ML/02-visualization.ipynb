# %% [markdown]
# # 2.可视化
#
# ## 单纬度
# - 直方图
# - 条形图/柱状图
# - 折线图
# - 箱线图
# - 饼状图
# - 小提琴图
#
# ## 多维度
# - 散点图
# - 热力图
# - 分组条形图
# - 点连趋势图
#
# ## 其他类型
# - 雷达
# - 地理
# - 词云
# - 树状图
#
# ## 多图组合
# - 单关系图
# - 多变量关系矩阵图
# - 数据分组包车图
#
# ## 三维图
# - 三维散点
# - 三维柱状
# - 三维折线图
# - 三维标签图
#
# ## 动态图
# - 动态趋势图
# - 动态轨迹图
#
# ## ref
# - matplotlib
# - seaborn
# - plotly
# - pyecharts
